# %%
start.data <- read.csv("start.csv")
x.start <- start.data$x
y.start <- start.data$y
plot(x.start,y.start,bg="red",pch=16,cex=0.5,xlim=c(0,120),ylim=c(0,120))
result.data <- read.csv("result.csv")
x.result <- result.data$x
y.result <- result.data$y
points(x.result,y.result,col=2,pch=16,cex=1)
# Out:
# plot without title

# %%
start.data <- read.csv("start.csv")
x.start <- start.data$x
y.start <- start.data$y
plot(x.start,y.start,bg="red",pch=16,cex=0.5,xlim=c(0,120),ylim=c(0,120))
result.data <- read.csv("result.csv")
x.result <- result.data$x
y.result <- result.data$y
points(x.result,y.result,col=2,pch=16,cex=0.5)
#lines(c(28,52,60,68,92,72,80,60,40,48,28),c(60,60,90,60,60,40,10,30,10,40,60))
lines(c(20,60),c(60,100))
lines(c(20,80),c(40,100))
lines(c(20,100),c(20,100))
lines(c(20,100),c(0,80))
lines(c(40,100),c(0,60))
lines(c(60,100),c(0,40))
# Out:
# plot without title
