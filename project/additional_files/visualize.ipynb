# %%
start.data <- read.csv("init.csv")
x.start <- start.data$x
y.start <- start.data$y
plot(x.start,y.start,bg="red",pch=16,cex=0.5)
#plot(x.start,y.start,bg="red",pch=16,cex=0.5,xlim=c(0,1000),ylim=c(0,1000))
result.data <- read.csv("result.csv")
x.result <- result.data$x
y.result <- result.data$y
points(x.result,y.result,col=2,pch=16,cex=0.5)
# Out:
# plot without title
